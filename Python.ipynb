# %% [markdown]
# <a href="https://colab.research.google.com/github/dazy1918/Python-Practice-Program-/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name= "Dazy"
age = 19
print(name)
print(age)
# Out:
# Dazy
# 19

# %%
s1 ="Hello"
s2= "Dazy"
s3 = s1+" "+s2
print(s3)
# Out:
# Hello Dazy

# %%
s1 = "Hello"
s2 = s1*4
print(s2)
# Out:
# HelloHelloHelloHello

# %%
n = int(input())
if n < 0:
    print("negative")
elif n > 0:
    print("positive")
else:
    print("zero")
# Out:
# 7
# positive

# %%
user_input = input()
char_list = list(user_input)
for i in range(len(char_list)):
    print(char_list[i])
# Out:
# Dazy
# D
# a
# z
# y

# %%
my_string = "dazy"
for char in my_string:
    print(char)
# Out:
# d
# a
# z
# y

# %%
count = 1
while count <=5:
  print(count)
  count+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Returns 0.1
result = 1 / 10
print(result)
# Out:
# 0.1

# %%
for var1 in range(3);
 print("Iteration" + str(var1+1)+)

# %%
num1 = 4
num2 = num1 + 1
num1 = 2
print("a)", num1, num2)

# %%
num1, num2 = 2, 6
num1, num2 = num2, num1 + 2
print("b)", num1, num2)
# Out:
# b) 6 4

# %%
num1, num2 = 2, 3
num3, num2 = num1, num3 + 1
print(num1, num2, num3)
# Out:
# c) Error: name 'num3' is not defined

# %%
x =5
cubee = x**3
print(x,cubee)
# Out:
# 5 8

# %%
P = float(input("Enter the P "))
r = float(input("Enter the r "))
t = float(input("Enter the t "))
A = P * (1 + r / 100) ** t
print(A)
# Out:
# Enter the P 4
# Enter the r 7
# Enter the t 2
# 4.5796

# %%
 weight = float(input("Enter "))
 height = float(input("Enter "))
 bmi = weight / (height ** 2)
 print(bmi)
# Out:
# Enter 40
# Enter 5.5
# 1.322314049586777

# %%
list1 = [123,"new Delhi",'123',5,8,7]
print(list1)
print(type(list1))
# Out:
# [123, 'new Delhi', '123', 5, 8, 7]
# <class 'list'>

# %%
length= 10
breadth=20
print(length*breadth)
# Out:
# 200

# %%
firstName= "Mohandas"
secondName = "Karamchand"
lastName = "Gandhi"
print(firstName+" "+secondName +" "+lastName)
# Out:
# Mohandas Karamchand Gandhi

# %%
length =5
breadth =10
sum = length+breadth
print(sum/2)
# Out:
# 7.5

# %%
name =input("Enter your name ")
print(name)
# Out:
# Enter your name dazy
# dazy

# %%
a = input("Enter the first number ")
b = input("Enter the second number ")
print(a + b)
# Out:
# Enter the first number 45
# Enter the second number67
# 4567

# %%
a = input("what is the color of rose ")
print("colour of rose is",a)
# Out:
# what is the color of rose red
# colour of rose is red

# %%
a = int(input("Enter the first number "))
b = int(input("Enter the second number "))
print(a + b)
# Out:
# Enter the first number 20
# Enter the second number 27
# 47

# %%
a= int(input("Enter the number "))
b= int(input("Enter the number "))
a=b
b=c
c=a
print(f"After swapping: a={a},b={b}")
# Out:
# Enter the number 7
# Enter the number 9
# After swapping: a=9,b=6

# %%
a= int(input("Enter the a "))
b= int(input("Enter the b "))
c= int(input("Enter the c "))
print((a+b)*c)

# %%
r = float(input())
Pi = 3.14
volume=(4/3)*Pi*(r**3)
print(f"{volume:.4f}")
# Out:
# 76
# 1837846.1867

# %%
dic1={'Fruit':'Apple','Climate':'cold','college':'kiet'}
print(dic1)
# Out:
# {'Fruit': 'Apple', 'Climate': 'cold', 'college': 'kiet'}

# %%
my_list=[1,2,3,4,5]
my_tuple=(4,5,6,7)
my_dic={'vegetable':'potato', 'age':'19'}
my_set={75,85,95}
my_string ="Python Programming"
print(my_list)
print(my_tuple)
print(my_dic)
print(my_set)
print(my_string)
# Out:
# [1, 2, 3, 4, 5]
# (4, 5, 6, 7)
# {'vegetable': 'potato', 'age': '19'}
# {75, 85, 95}
# Python Programming

# %%
num1=int(10)
num2=int(5)
print(num1+num2)
print(num1/num2)
print(num1*num2)
print(num1%num2)
print(num1**num2)
print(num1//num2)
# Out:
# 15
# 2.0
# 50
# 0
# 100000
# 2

# %%
s = float(input("Enter the Price "))
print("Price of product is ",s)
# Out:
# Enter the Price 5
# Price of product is  5.0

# %%
set1={'new delhi','jkl',1,2,2,3,3,4,5}
print(set1)
# Out:
# {1, 2, 3, 4, 'jkl', 5, 'new delhi'}

# %%
name = input("Enter the name ")
age = input("Enter the age ")
print("My name and age is" ,name,age)
# Out:
# Enter the name Dazy
# Enter the age 19
# My name and age is Dazy 19

# %%
a = input("Enter First Number ")
b = input("Enter Second number ")
print("First Number is ",a)
print("Second Number is ",b)
# Out:
# Enter First Number 4
# Enter Second number 6
# First Number is  4
# Second Number is  6

# %%
a = float(input("Enter the length "))
b = float(input("Enter the breadth "))
area = a * b
print("Area ", area)
# Out:
# Enter the length 89
# Enter the breadth 65
# Area  5785.0

# %%
num1= 20
print(id(num1))
# Out:
# 11654984

# %%
a =10
name ="Riya"
print(type(a))
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = int((3 + 4j).real)
print(x)
print(type(x))
# Out:
# 3
# <class 'int'>

# %%
x = int((3 + 4j).imag)
print(x)
print(type(x))
# Out:
# 4
# <class 'int'>

# %%
x = int (3 + 4)
print(x)
print(type(x))
# Out:
# 7
# <class 'int'>
